# %%
# Import the packages needed for the examples included in this notebook
import numpy as np
import matplotlib.pyplot as plt

# Import the python-control package
try:
    import control as ct
    print("python-control", ct.__version__)
except ImportError:
    # %pip install control
    import control as ct
# Out:
# python-control 0.10.1

# %%
s = ct.tf('s')
sys = 5 * (s + 10)/(s**2 + 2*s + 1)

# %%
response = ct.step_response(sys)
plt.plot(response.time, response.outputs)

# %%
response.time
# Out:
# array([0.        , 0.06977531, 0.13955061, 0.20932592, 0.27910122,
#        0.34887653, 0.41865184, 0.48842714, 0.55820245, 0.62797775,
#        0.69775306, 0.76752836, 0.83730367, 0.90707898, 0.97685428,
#        1.04662959, 1.11640489, 1.1861802 , 1.25595551, 1.32573081,
#        1.39550612, 1.46528142, 1.53505673, 1.60483203, 1.67460734,
#        1.74438265, 1.81415795, 1.88393326, 1.95370856, 2.02348387,
#        2.09325918, 2.16303448, 2.23280979, 2.30258509, 2.3723604 ,
#        2.4421357 , 2.51191101, 2.58168632, 2.65146162, 2.72123693,
#        2.79101223, 2.86078754, 2.93056285, 3.00033815, 3.07011346,
#        3.13988876, 3.20966407, 3.27943937, 3.34921468, 3.41898999,
#        3.48876529, 3.5585406 , 3.6283159 , 3.69809121, 3.76786652,
#        3.83764182, 3.90741713, 3.97719243, 4.04696774, 4.11674305,
#        4.18651835, 4.25629366, 4.32606896, 4.39584427, 4.46561957,
#        4.53539488, 4.60517019, 4.67494549, 4.7447208 , 4.8144961 ,
# ...

# %%
timepts = np.linspace(0, 20, 1000)

# %%
timepts
# Out:
# array([ 0.        ,  0.02002002,  0.04004004,  0.06006006,  0.08008008,
#         0.1001001 ,  0.12012012,  0.14014014,  0.16016016,  0.18018018,
#         0.2002002 ,  0.22022022,  0.24024024,  0.26026026,  0.28028028,
#         0.3003003 ,  0.32032032,  0.34034034,  0.36036036,  0.38038038,
#         0.4004004 ,  0.42042042,  0.44044044,  0.46046046,  0.48048048,
#         0.5005005 ,  0.52052052,  0.54054054,  0.56056056,  0.58058058,
#         0.6006006 ,  0.62062062,  0.64064064,  0.66066066,  0.68068068,
#         0.7007007 ,  0.72072072,  0.74074074,  0.76076076,  0.78078078,
#         0.8008008 ,  0.82082082,  0.84084084,  0.86086086,  0.88088088,
#         0.9009009 ,  0.92092092,  0.94094094,  0.96096096,  0.98098098,
#         1.001001  ,  1.02102102,  1.04104104,  1.06106106,  1.08108108,
#         1.1011011 ,  1.12112112,  1.14114114,  1.16116116,  1.18118118,
#         1.2012012 ,  1.22122122,  1.24124124,  1.26126126,  1.28128128,
# ...

# %%
response = ct.step_response(sys, timepts)
plt.plot(response.time, response.outputs)

# %%
s = ct.tf('s')
sys2 = (s**2/1.4142)/(s**2 + 45.5*s + 3535)

# %%
response = ct.step_response(sys2)
plt.plot(response.time, response.outputs)

# %%
response = ct.frequency_response([sys2])

# %%
ct.bode_plot(response, initial_phase=0)

# %%
response = ct.pole_zero_map(sys2)
ct.pole_zero_plot(response)

# %%
response = ct.pole_zero_map(sys2)
ct.pole_zero_plot(response)

# %%
s = ct.tf('s')
butter6 = 1/((s**2 + 0.5176*s + 1)*(s**2+1.414*s+1)*(s**2+1.932*s+1))

# %%
response = ct.pole_zero_map(butter6)
ct.pole_zero_plot(response)

# %%
from sympy import *
from sympy import __version__ as sympy_version
print("Sympy version is: \t" + sympy_version)
x = Symbol('x')
# from sympy.abc import x     # Prepare the variable x.
init_printing()             # Make things print nicely
# Out:
# Sympy version is: 	1.14.0

# %%
R=5
C=1
L=1

# %%
s = ct.tf('s')
RLC1=R/(R*L*C*s**2+L*s+R)

# %%
response = ct.pole_zero_map(RLC1)
ct.pole_zero_plot(response)

# %%
response = ct.frequency_response([RLC1])

# %%
ct.bode_plot(response, initial_phase=0)

# %%
K=4
R=1
C=1

# %%
VCVS1=K/((R*C*s)*(R*C*s)+(3-K)*R*C*s+1)

# %%
response = ct.pole_zero_map(VCVS1)
ct.pole_zero_plot(response)

# %%
K=0.5
R=10e3
C=100e-9

# %%
VCVS2=K/((R*C*s)**2+(3-K)*R*C*s+1)

# %%
response = ct.pole_zero_map(VCVS2)
ct.pole_zero_plot(response)

# %%
response = ct.frequency_response([VCVS2])
ct.bode_plot(response, initial_phase=0)

# %%
response = ct.step_response(VCVS2)
plt.plot(response.time, response.outputs)

# %%
import numpy as np
starttime = 0
endtime = 2e-3
aantal_stappen = 2500
endtime = starttime+stepsize*aantal_stappen
print(endtime)
tstep = np.linspace(starttime,endtime,aantal_stappen)
# Out:
# 2.5

# %%
stepsize=1e-3
baseper=2500.0*stepsize
print(baseper)
fbase = 1.0/baseper
f=2
phase = 2.0*np.pi*f*tstep
print(fbase)
print(f)
y = np.sin(2.0*np.pi*(f)*tstep)
print(y)
# Out:
# 2.5
# 0.4
# 2
# [ 0.00000000e+00  1.25710680e-02  2.51401494e-02 ... -2.51401494e-02
#  -1.25710680e-02 -1.22464680e-15]

# %%
plt.plot(y)

# %%
import math
y = (y*127)

# %%
y
# Out:
# array([ 0.00000000e+00,  1.59652564e+00,  3.19279897e+00, ...,
#        -3.19279897e+00, -1.59652564e+00, -1.55530143e-13])

# %%
plt.plot(y)

# %%
h=np.round(y)

# %%
h
# Out:
# array([ 0.,  2.,  3., ..., -3., -2., -0.])

# %%
plt.plot(h)
