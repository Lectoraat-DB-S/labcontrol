# %% [markdown]
# # Afronden installatie Labcontrol
# Dat jij deze tekst op nu op je scherm ziet, betekent dat:
# - er een directory `labcontrol` op jouw computer staat.
# - Dat jij, via een snelkoppeling in deze directory, succesvol een  `Jupyter Notebook` instantie hebt kunnen opstarten.
# - Dat jij, in het startscherm van `Jupyter Notebook`, het bestand `getStarted.ipynb` hebt gevonden en kunnen openen.
#
# Daarmee is jouw computer bijna geschikt voor het draaien van labcontrol. Bijna. Jouw computer moet nog weten hoe de labapparatuur moet worden bestuurd. Daarvoor heb je de VISA driver van National Instruments nodig. Je kunt deze driver vinden op hun website, maar om jou sneller aan de labcontrol te krijgen, hebben we de installer vooraf gedownload en opgenomen in de labcontrol installer. Deze installer gaan we nu, via deze notebook, start zodat de driver geïnstalleerd wordt. Daarnaast installeren we via deze notebook de benodigde Python binding.
#
# Voor diegenen die nog nooit eerder met een `Jupyter Notebook` heeft gewerkt, of hebben gezien: zie notebooks als webpagina's waarin je blokken met tekst en code kunt vinden. Je zou het ook kunnen zien als een Word-pagina waar je overal en nergens grafische rekenmachines in kunt plakken. Notebooks zijn enorm flexibel: tekst- en codeblokken zijn beiden eenvoudig aanpasbaar, maar alleen codeblokken zijn (opnieuw) executeerbaar. Om een codeblok uit te kunnen voeren, moet je op het afspeelknopje drukken. Het knopje vind je boven in de Jupyter Notebook pagina. Zie onderstaand figuur:
# ![image.png](attachment:image.png)
#
# Om de VISA installer te starten moet op onderstaand codeblok klikken en daarna afspelen klikken. Tijdens het opstarten wordt gevraagd om toestemming. Kies voor 'Ja'.
# Toelichting switches bij onderstaande instructie:
#   --accept-eulas: user accepteert bijvoorbaat alle licentie overeenkomsten.
#   --passive: geen user input nodig
# Deze werkwijze voorkomt 'hangen' van de installer, omdat de gebruiker heeft nagelaten ergens in het installatieproces op 'Ja' te klikken.

# %%
# !start "" /wait "C:\labcontrol\VISAdrv\ni-488.2_25.0_online.exe" --passive --accept-eulas --prevent-reboot

# %% [markdown]
# Wacht totdat NI VISA driver geinstalleerd is, voordat je verder gaat met de laatste installatiestap.
#
# Via onderstaand codeblok wordt als laatste stap de pyvisa package in de Python omgeving van deze Jupyter Notebook geïnstalleerd. Deze Python binding is noodzakelijk om labapparatuur vanuit Python scripts te kunnen besturen.

# %%
# %pip install pyvisa

# %% [markdown]
# Wacht totdat de installatie van pyvisa volledig is afgerond. Jouw computer is nu geschikt voor labcontrol! Je kunt deze Jupyter Notebook sluiten.
